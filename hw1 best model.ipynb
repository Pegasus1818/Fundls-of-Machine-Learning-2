# %% [markdown]
# # Baseline Code for HW1
#
# This is just the baseline code to set up the basic function you need. You need to modify the code yourself to achieve a better result.

# %% [markdown]
# ## Import packages you need

# %%
# PyTorch
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# For data preprocess
import numpy as np
import pandas as pd
import csv
import os
from sklearn.feature_selection import SelectKBest,f_regression
from sklearn import preprocessing

# For plotting
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

myseed = 666  # set a random seed for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(myseed)

# %% [markdown]
# ## Basic Function
# Do not modify this part

# %%
def get_device():
    ''' Get device (if GPU is available, use GPU) '''
    return 'cuda' if torch.cuda.is_available() else 'cpu'

def plot_learning_curve(loss_record, title=''):
    ''' Plot learning curve of your DNN (train & dev loss) '''
    total_steps = len(loss_record['train'])
    x_1 = range(total_steps)
    x_2 = x_1[::len(loss_record['train']) // len(loss_record['dev'])]
    figure(figsize=(6, 4))
    plt.plot(x_1, loss_record['train'], c='tab:red', label='train')
    plt.plot(x_2, loss_record['dev'], c='tab:cyan', label='dev')
    plt.ylim(0.0, 5.)
    plt.xlabel('Training steps')
    plt.ylabel('MSE loss')
    plt.title('Learning curve of {}'.format(title))
    plt.legend()
    plt.show()
    
def plot_pred(dv_set, model, device, lim=35., preds=None, targets=None):
    ''' Plot prediction of your DNN '''
    if preds is None or targets is None:
        model.eval()
        preds, targets = [], []
        for x, y in dv_set:
            x, y = x.to(device), y.to(device)
            with torch.no_grad():
                pred = model(x)
                preds.append(pred.detach().cpu())
                targets.append(y.detach().cpu())
        preds = torch.cat(preds, dim=0).numpy()
        targets = torch.cat(targets, dim=0).numpy()

    figure(figsize=(5, 5))
    plt.scatter(targets, preds, c='r', alpha=0.5)
    plt.plot([-0.2, lim], [-0.2, lim], c='b')
    plt.xlim(-0.2, lim)
    plt.ylim(-0.2, lim)
    plt.xlabel('Truth value')
    plt.ylabel('predicted value')
    plt.title('Truth v.s. Prediction')
    plt.show()

# %%
get_device()
# Out:
# 'cuda'

# %% [markdown]
# ## Data and Preprocess
# The function below used to:
# 1. Read the csv files into python
# 2. Choose features (you can choose yourself)
# 3. Split data into training and validation sets.
# 4. Normalization

# %%
def f_reg(x,y):
    x_scaled = pd.DataFrame(preprocessing.scale(x))    
    skb = SelectKBest(score_func=f_regression, k=5)
    fmodel = skb.fit(x_scaled,y)
    fea = pd.DataFrame(x.columns)
    scor = pd.DataFrame(fmodel.scores_)
    res = pd.concat([fea,scor],axis=1)
    res.columns = ['Features','Score']
    print(res.nlargest(20,'Score'))

tra=pd.read_csv('HW1.train.csv')
x = tra[tra.columns[1:94]]
y = tra[tra.columns[94]]
f_reg(x,y)
# Out:
#               Features          Score
# 75   tested_positive.1  112995.138726
# 57     tested_positive   53249.271791
# 42        hh_cmnty_cli    7783.153184
# 60      hh_cmnty_cli.1    7713.712252
# 78      hh_cmnty_cli.2    7572.365612
# 43      nohh_cmnty_cli    6954.915166
# 61    nohh_cmnty_cli.1    6863.334251
# 79    nohh_cmnty_cli.2    6708.860666
# 58               cli.1    5176.487362
# 40                 cli    5133.480064
# 76               cli.2    5125.427679
# 41                 ili    4745.448707
# 59               ili.1    4739.143963
# 77               ili.2    4665.965887
# 92  worried_finances.2     677.968387
# 74  worried_finances.1     653.347601
# 56    worried_finances     626.476595
# 87    public_transit.2     526.050157
# 69    public_transit.1     519.843557
# 51      public_transit     514.690608

# %% [markdown]
# feats = [75,57,42,60,78,43,61,79,58,40,76,41,59,77,92,74,56,87,69,51]
#     20: 0.8386
#     14: 0.8506 2791
#     10: 0.8151
#     5: 0.8334

# %%
class Dataprocess(Dataset):
    def __init__(self,
                 path,
                 mode='train',
                 modify=False):
        self.mode = mode

        # Read csv file
        with open(path, 'r') as f:
            data = list(csv.reader(f))
            data = np.array(data[1:])[:, 1:].astype(float)
        
        if modify == False:
            feats = list(range(93))
        else:
            # Hint:Feature Selection
            feats = [75,57,42,60,78,43,61,79,58,40,76,41,59,77]
            
            
            

        if mode == 'test':
            # Testing set
            data = data[:, feats]
            self.data = torch.FloatTensor(data)
        else:
            # Training set
            target = data[:, -1]
            data = data[:, feats]

            # Splitting data into training and validation sets
            if mode == 'train':
                indices = [i for i in range(len(data)) if i % 10 != 0]
            elif mode == 'dev':
                indices = [i for i in range(len(data)) if i % 10 == 0]
            
            # Convert data into PyTorch tensors
            self.data = torch.FloatTensor(data[indices])
            self.target = torch.FloatTensor(target[indices])

        # Normalize features
        self.data[:, 40:] = \
            (self.data[:, 40:] - self.data[:, 40:].mean(dim=0, keepdim=True)) \
            / self.data[:, 40:].std(dim=0, keepdim=True)

        self.dim = self.data.shape[1]

        print('Finished reading the {} set of COVID19 Dataset ({} samples found, each dim = {})'
              .format(mode, len(self.data), self.dim))

    def __getitem__(self, index):
        # Returns one sample at a time
        if self.mode in ['train', 'dev']:
            # For training
            return self.data[index], self.target[index]
        else:
            # For testing
            return self.data[index]

    def __len__(self):
        # Returns the size of the dataset
        return len(self.data)

# %% [markdown]
# ## Dataloader
# Loads data into batches.

# %%
def dataloader(path, mode, batch_size, n_jobs=0, modify=False):
    dataset = Dataprocess(path, mode=mode, modify=modify)
    dataloader = DataLoader(
        dataset, batch_size,
        shuffle=(mode == 'train'), drop_last=False,
        num_workers=n_jobs, pin_memory=True)
    return dataloader

# %% [markdown]
# ## Define DNN by pytorch
# The DNN consists of 2 fully-connected layers with ReLU activation function

# %%
class NeuralNet(nn.Module):
    def __init__(self, input_dim):
        super(NeuralNet, self).__init__()
        
        # Try to modify this DNN to achieve better performance
        self.net = nn.Sequential(            
            nn.Linear(input_dim, 128),
            nn.LeakyReLU(0.1),
            nn.Dropout(p=0.06),
            nn.Linear(128, 32),
            nn.LeakyReLU(0.1),
            nn.Linear(32, 1)
            
#             nn.Linear(input_dim, 64),
#             nn.Softplus(),
#             nn.Dropout(p=0.06),
#             nn.Linear(64, 1)
        )

        # Loss function MSE
        self.criterion = nn.MSELoss(reduction='mean')

    def forward(self, x):
        ''' Given input of size (batch_size x input_dim), compute output of the network '''
        return self.net(x).squeeze(1)

    def cal_loss(self, pred, target):
        ''' Calculate loss '''
        # You may try regularization here
        regularization_loss = 0
        for param in model.parameters():
             regularization_loss += torch.sum(param**2)
        return self.criterion(pred, target) + 0.00075 * regularization_loss

# %% [markdown]
# ## Training

# %%
def train(tr_set, dv_set, model, config, device):

    n_epochs = config['n_epochs']  # Maximum number of epochs

    # Setup optimizer
    optimizer = getattr(torch.optim, config['optimizer'])(
        model.parameters(), **config['optim_hparas'])

    min_mse = 1000.
    loss_record = {'train': [], 'dev': []}      # for recording training loss
    early_stop_cnt = 0
    epoch = 0
    while epoch < n_epochs:
        model.train()                           # set model to training mode
        for x, y in tr_set:                     # iterate through the dataloader
            optimizer.zero_grad()               # set gradient to zero
            x, y = x.to(device), y.to(device)   # move data to device (cpu/cuda)
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
            mse_loss.backward()                 # compute gradient (backpropagation)
            optimizer.step()                    # update model with optimizer
            loss_record['train'].append(mse_loss.detach().cpu().item())

        dev_mse = dev(dv_set, model, device)
        if dev_mse < min_mse:
            # Save model if your model improved
            min_mse = dev_mse
            print('Saving model (epoch = {:4d}, loss = {:.4f})'
                .format(epoch + 1, min_mse))
            torch.save(model.state_dict(), config['save_path'])  # Save model to specified path
            early_stop_cnt = 0
        else:
            early_stop_cnt += 1

        epoch += 1
        loss_record['dev'].append(dev_mse)
        if early_stop_cnt > config['early_stop']:
            break

    print('Finished training after {} epochs'.format(epoch))
    return min_mse, loss_record

# %% [markdown]
# ## Validation

# %%
def dev(dv_set, model, device):
    model.eval()                                # set model to evalutation mode
    total_loss = 0
    for x, y in dv_set:                         # iterate through the dataloader
        x, y = x.to(device), y.to(device)       # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
        total_loss += mse_loss.detach().cpu().item() * len(x)  # accumulate loss
    total_loss = total_loss / len(dv_set.dataset)              # compute averaged loss

    return total_loss

# %% [markdown]
# ## Testing

# %%
def test(tt_set, model, device):
    model.eval()                                # set model to evalutation mode
    preds = []
    for x in tt_set:                            # iterate through the dataloader
        x = x.to(device)                        # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            preds.append(pred.detach().cpu())   # collect prediction
    preds = torch.cat(preds, dim=0).numpy()     # concatenate all predictions and convert to a numpy array
    return preds

# %% [markdown]
# ## Hyper-parameters for DNN

# %%
device = get_device()                 # get the current available device ('cpu' or 'cuda')
os.makedirs('models', exist_ok=True)  # The trained model will be saved to ./models/
modify = True                     # Need selection

# Tune these hyper-parameters to improve your model
config = {
    'n_epochs': 10000,                # maximum number of epochs
    'batch_size': 250,               # mini-batch size for dataloader
#     'optimizer': 'SGD',              # optimization algorithm (optimizer in torch.optim)
#     'optim_hparas': {                # hyper-parameters for the optimizer (depends on which optimizer you are using)
#         'lr': 0.001,                 # learning rate of SGD
#     },
    'optimizer':"Adam",
    'optim_hparas':{
        'lr':1e-4,
        'betas':(0.9, 0.999),
    },
    'early_stop': 500,               # early stopping epochs (the number epochs since your model's last improvement)
    'save_path': 'models/model.pth'  # your model will be saved here
}

# %% [markdown]
# ## Read the dataset

# %%
train_path = 'HW1.train.csv'  # path to training data
test_path = 'HW1.test.csv'   # path to testing data

# train_path='covid.train.csv'
# test_path='covid.test.csv'

train_set = dataloader(train_path, 'train', config['batch_size'], modify=modify)
validation_set = dataloader(train_path, 'dev', config['batch_size'], modify=modify)
test_set = dataloader(test_path, 'test', config['batch_size'], modify=modify)
# Out:
# Finished reading the train set of COVID19 Dataset (1800 samples found, each dim = 14)
# Finished reading the dev set of COVID19 Dataset (200 samples found, each dim = 14)
# Finished reading the test set of COVID19 Dataset (500 samples found, each dim = 14)

# %% [markdown]
# ## Try to train your DNN

# %%
model = NeuralNet(train_set.dataset.dim).to(device)  # Construct model and move to device

# %%
model_loss, model_loss_record = train(train_set, validation_set, model, config, device)
# Out:
# Saving model (epoch =    1, loss = 288.9338)
# Saving model (epoch =    2, loss = 245.8745)
# Saving model (epoch =    3, loss = 205.8472)
# Saving model (epoch =    4, loss = 169.2721)
# Saving model (epoch =    5, loss = 135.8870)
# Saving model (epoch =    6, loss = 107.6893)
# Saving model (epoch =    7, loss = 84.3066)
# Saving model (epoch =    8, loss = 65.3925)
# Saving model (epoch =    9, loss = 50.0697)
# Saving model (epoch =   10, loss = 36.9868)
# Saving model (epoch =   11, loss = 27.3498)
# Saving model (epoch =   12, loss = 20.4585)
# Saving model (epoch =   13, loss = 15.8999)
# Saving model (epoch =   14, loss = 13.1107)
# Saving model (epoch =   15, loss = 11.6081)
# Saving model (epoch =   16, loss = 10.8615)
# Saving model (epoch =   17, loss = 10.5175)
# Saving model (epoch =   18, loss = 10.3534)
# Saving model (epoch =   19, loss = 10.2411)
# Saving model (epoch =   20, loss = 10.1281)
# Saving model (epoch =   21, loss = 10.0022)
# Saving model (epoch =   22, loss = 9.8641)
# Saving model (epoch =   23, loss = 9.7237)
# Saving model (epoch =   24, loss = 9.5602)
# Saving model (epoch =   25, loss = 9.3978)
# Saving model (epoch =   26, loss = 9.2296)
# Saving model (epoch =   27, loss = 9.0596)
# Saving model (epoch =   28, loss = 8.8742)
# Saving model (epoch =   29, loss = 8.6834)
# Saving model (epoch =   30, loss = 8.4850)
# Saving model (epoch =   31, loss = 8.2846)
# Saving model (epoch =   32, loss = 8.0957)
# Saving model (epoch =   33, loss = 7.8974)
# Saving model (epoch =   34, loss = 7.6983)
# Saving model (epoch =   35, loss = 7.5168)
# Saving model (epoch =   36, loss = 7.3438)
# Saving model (epoch =   37, loss = 7.1769)
# Saving model (epoch =   38, loss = 6.9968)
# Saving model (epoch =   39, loss = 6.8267)
# Saving model (epoch =   40, loss = 6.6605)
# Saving model (epoch =   41, loss = 6.5003)
# Saving model (epoch =   42, loss = 6.3565)
# Saving model (epoch =   43, loss = 6.2193)
# Saving model (epoch =   44, loss = 6.0796)
# Saving model (epoch =   45, loss = 5.9427)
# Saving model (epoch =   46, loss = 5.8021)
# Saving model (epoch =   47, loss = 5.6685)
# Saving model (epoch =   48, loss = 5.5216)
# Saving model (epoch =   49, loss = 5.3820)
# Saving model (epoch =   50, loss = 5.2327)
# Saving model (epoch =   51, loss = 5.0926)
# Saving model (epoch =   52, loss = 4.9543)
# Saving model (epoch =   53, loss = 4.8227)
# Saving model (epoch =   54, loss = 4.6850)
# Saving model (epoch =   55, loss = 4.5750)
# Saving model (epoch =   56, loss = 4.4431)
# Saving model (epoch =   57, loss = 4.3198)
# Saving model (epoch =   58, loss = 4.2128)
# Saving model (epoch =   59, loss = 4.0873)
# Saving model (epoch =   60, loss = 3.9439)
# Saving model (epoch =   61, loss = 3.8220)
# Saving model (epoch =   62, loss = 3.7050)
# Saving model (epoch =   63, loss = 3.5921)
# Saving model (epoch =   64, loss = 3.4755)
# Saving model (epoch =   65, loss = 3.3596)
# Saving model (epoch =   66, loss = 3.2490)
# Saving model (epoch =   67, loss = 3.1419)
# Saving model (epoch =   68, loss = 3.0362)
# Saving model (epoch =   69, loss = 2.9373)
# Saving model (epoch =   70, loss = 2.8451)
# Saving model (epoch =   71, loss = 2.7626)
# Saving model (epoch =   72, loss = 2.6799)
# Saving model (epoch =   73, loss = 2.6006)
# Saving model (epoch =   74, loss = 2.5286)
# Saving model (epoch =   75, loss = 2.4695)
# Saving model (epoch =   76, loss = 2.4203)
# Saving model (epoch =   77, loss = 2.3475)
# Saving model (epoch =   78, loss = 2.2821)
# Saving model (epoch =   79, loss = 2.2344)
# Saving model (epoch =   80, loss = 2.2109)
# Saving model (epoch =   81, loss = 2.1585)
# Saving model (epoch =   82, loss = 2.1053)
# Saving model (epoch =   83, loss = 2.0528)
# Saving model (epoch =   84, loss = 2.0203)
# Saving model (epoch =   85, loss = 1.9848)
# Saving model (epoch =   86, loss = 1.9567)
# Saving model (epoch =   87, loss = 1.9207)
# Saving model (epoch =   88, loss = 1.8803)
# Saving model (epoch =   89, loss = 1.8239)
# Saving model (epoch =   90, loss = 1.7882)
# Saving model (epoch =   91, loss = 1.7861)
# Saving model (epoch =   92, loss = 1.7726)
# Saving model (epoch =   93, loss = 1.7252)
# Saving model (epoch =   94, loss = 1.7064)
# Saving model (epoch =   95, loss = 1.6977)
# Saving model (epoch =   96, loss = 1.6645)
# Saving model (epoch =   97, loss = 1.6457)
# Saving model (epoch =   98, loss = 1.6320)
# Saving model (epoch =   99, loss = 1.6278)
# Saving model (epoch =  100, loss = 1.6233)
# Saving model (epoch =  101, loss = 1.6051)
# Saving model (epoch =  102, loss = 1.5774)
# Saving model (epoch =  103, loss = 1.5699)
# Saving model (epoch =  106, loss = 1.5699)
# Saving model (epoch =  107, loss = 1.5423)
# Saving model (epoch =  108, loss = 1.5370)
# Saving model (epoch =  111, loss = 1.5174)
# Saving model (epoch =  112, loss = 1.5058)
# Saving model (epoch =  117, loss = 1.5047)
# Saving model (epoch =  118, loss = 1.5030)
# Saving model (epoch =  120, loss = 1.4861)
# Saving model (epoch =  121, loss = 1.4839)
# Saving model (epoch =  124, loss = 1.4810)
# Saving model (epoch =  127, loss = 1.4777)
# Saving model (epoch =  128, loss = 1.4760)
# Saving model (epoch =  129, loss = 1.4623)
# Saving model (epoch =  132, loss = 1.4553)
# Saving model (epoch =  135, loss = 1.4497)
# Saving model (epoch =  137, loss = 1.4414)
# Saving model (epoch =  138, loss = 1.4370)
# Saving model (epoch =  142, loss = 1.4362)
# Saving model (epoch =  143, loss = 1.4310)
# Saving model (epoch =  149, loss = 1.4310)
# Saving model (epoch =  151, loss = 1.4269)
# Saving model (epoch =  152, loss = 1.4235)
# Saving model (epoch =  159, loss = 1.4181)
# Saving model (epoch =  161, loss = 1.4137)
# Saving model (epoch =  162, loss = 1.4126)
# Saving model (epoch =  168, loss = 1.4095)
# Saving model (epoch =  173, loss = 1.4058)
# Saving model (epoch =  174, loss = 1.3968)
# Saving model (epoch =  178, loss = 1.3950)
# Saving model (epoch =  184, loss = 1.3877)
# Saving model (epoch =  188, loss = 1.3825)
# Saving model (epoch =  197, loss = 1.3787)
# Saving model (epoch =  204, loss = 1.3762)
# Saving model (epoch =  208, loss = 1.3654)
# Saving model (epoch =  215, loss = 1.3633)
# Saving model (epoch =  217, loss = 1.3613)
# Saving model (epoch =  218, loss = 1.3517)
# Saving model (epoch =  223, loss = 1.3490)
# Saving model (epoch =  230, loss = 1.3449)
# Saving model (epoch =  233, loss = 1.3432)
# Saving model (epoch =  234, loss = 1.3403)
# Saving model (epoch =  246, loss = 1.3318)
# Saving model (epoch =  260, loss = 1.3236)
# Saving model (epoch =  266, loss = 1.3145)
# Saving model (epoch =  270, loss = 1.3131)
# Saving model (epoch =  274, loss = 1.3125)
# Saving model (epoch =  278, loss = 1.3094)
# Saving model (epoch =  285, loss = 1.3085)
# Saving model (epoch =  286, loss = 1.3081)
# Saving model (epoch =  289, loss = 1.3075)
# Saving model (epoch =  291, loss = 1.3023)
# Saving model (epoch =  292, loss = 1.2991)
# Saving model (epoch =  296, loss = 1.2985)
# Saving model (epoch =  302, loss = 1.2930)
# Saving model (epoch =  305, loss = 1.2895)
# Saving model (epoch =  313, loss = 1.2872)
# Saving model (epoch =  316, loss = 1.2862)
# Saving model (epoch =  317, loss = 1.2853)
# Saving model (epoch =  320, loss = 1.2781)
# Saving model (epoch =  328, loss = 1.2719)
# Saving model (epoch =  331, loss = 1.2717)
# Saving model (epoch =  341, loss = 1.2687)
# Saving model (epoch =  342, loss = 1.2673)
# Saving model (epoch =  345, loss = 1.2599)
# Saving model (epoch =  355, loss = 1.2573)
# Saving model (epoch =  359, loss = 1.2543)
# Saving model (epoch =  368, loss = 1.2425)
# Saving model (epoch =  374, loss = 1.2413)
# Saving model (epoch =  376, loss = 1.2388)
# Saving model (epoch =  383, loss = 1.2353)
# Saving model (epoch =  386, loss = 1.2345)
# Saving model (epoch =  391, loss = 1.2267)
# Saving model (epoch =  393, loss = 1.2257)
# Saving model (epoch =  402, loss = 1.2243)
# Saving model (epoch =  405, loss = 1.2215)
# Saving model (epoch =  411, loss = 1.2127)
# Saving model (epoch =  416, loss = 1.2115)
# Saving model (epoch =  430, loss = 1.2098)
# Saving model (epoch =  433, loss = 1.2002)
# Saving model (epoch =  442, loss = 1.1990)
# Saving model (epoch =  456, loss = 1.1955)
# Saving model (epoch =  460, loss = 1.1941)
# Saving model (epoch =  461, loss = 1.1884)
# Saving model (epoch =  469, loss = 1.1818)
# Saving model (epoch =  473, loss = 1.1805)
# Saving model (epoch =  475, loss = 1.1755)
# Saving model (epoch =  490, loss = 1.1664)
# Saving model (epoch =  493, loss = 1.1662)
# Saving model (epoch =  498, loss = 1.1640)
# Saving model (epoch =  506, loss = 1.1576)
# Saving model (epoch =  513, loss = 1.1557)
# Saving model (epoch =  517, loss = 1.1541)
# Saving model (epoch =  520, loss = 1.1480)
# Saving model (epoch =  526, loss = 1.1435)
# Saving model (epoch =  530, loss = 1.1423)
# Saving model (epoch =  546, loss = 1.1410)
# Saving model (epoch =  550, loss = 1.1375)
# Saving model (epoch =  553, loss = 1.1323)
# Saving model (epoch =  557, loss = 1.1319)
# Saving model (epoch =  563, loss = 1.1276)
# Saving model (epoch =  568, loss = 1.1229)
# Saving model (epoch =  573, loss = 1.1226)
# Saving model (epoch =  579, loss = 1.1137)
# Saving model (epoch =  588, loss = 1.1068)
# Saving model (epoch =  595, loss = 1.1061)
# Saving model (epoch =  599, loss = 1.1040)
# Saving model (epoch =  603, loss = 1.1006)
# Saving model (epoch =  606, loss = 1.1000)
# Saving model (epoch =  610, loss = 1.0936)
# Saving model (epoch =  617, loss = 1.0905)
# Saving model (epoch =  618, loss = 1.0870)
# Saving model (epoch =  628, loss = 1.0864)
# Saving model (epoch =  634, loss = 1.0822)
# Saving model (epoch =  636, loss = 1.0798)
# Saving model (epoch =  645, loss = 1.0786)
# Saving model (epoch =  650, loss = 1.0699)
# Saving model (epoch =  656, loss = 1.0650)
# Saving model (epoch =  662, loss = 1.0650)
# Saving model (epoch =  664, loss = 1.0614)
# Saving model (epoch =  667, loss = 1.0578)
# Saving model (epoch =  671, loss = 1.0569)
# Saving model (epoch =  675, loss = 1.0428)
# Saving model (epoch =  680, loss = 1.0327)
# Saving model (epoch =  687, loss = 1.0249)
# Saving model (epoch =  689, loss = 1.0234)
# Saving model (epoch =  698, loss = 1.0233)
# Saving model (epoch =  702, loss = 1.0226)
# Saving model (epoch =  706, loss = 1.0200)
# Saving model (epoch =  708, loss = 1.0193)
# Saving model (epoch =  712, loss = 1.0111)
# Saving model (epoch =  721, loss = 1.0048)
# Saving model (epoch =  729, loss = 1.0026)
# Saving model (epoch =  734, loss = 0.9986)
# Saving model (epoch =  738, loss = 0.9960)
# Saving model (epoch =  741, loss = 0.9936)
# Saving model (epoch =  743, loss = 0.9930)
# Saving model (epoch =  751, loss = 0.9915)
# Saving model (epoch =  762, loss = 0.9857)
# Saving model (epoch =  774, loss = 0.9829)
# Saving model (epoch =  781, loss = 0.9809)
# Saving model (epoch =  790, loss = 0.9782)
# Saving model (epoch =  797, loss = 0.9772)
# Saving model (epoch =  801, loss = 0.9771)
# Saving model (epoch =  804, loss = 0.9753)
# Saving model (epoch =  806, loss = 0.9747)
# Saving model (epoch =  814, loss = 0.9745)
# Saving model (epoch =  815, loss = 0.9730)
# Saving model (epoch =  817, loss = 0.9720)
# Saving model (epoch =  820, loss = 0.9713)
# Saving model (epoch =  828, loss = 0.9674)
# Saving model (epoch =  830, loss = 0.9664)
# Saving model (epoch =  837, loss = 0.9634)
# Saving model (epoch =  843, loss = 0.9624)
# Saving model (epoch =  847, loss = 0.9605)
# Saving model (epoch =  850, loss = 0.9593)
# Saving model (epoch =  858, loss = 0.9566)
# Saving model (epoch =  863, loss = 0.9563)
# Saving model (epoch =  872, loss = 0.9501)
# Saving model (epoch =  875, loss = 0.9489)
# Saving model (epoch =  879, loss = 0.9481)
# Saving model (epoch =  881, loss = 0.9471)
# Saving model (epoch =  884, loss = 0.9458)
# Saving model (epoch =  891, loss = 0.9455)
# Saving model (epoch =  893, loss = 0.9423)
# Saving model (epoch =  895, loss = 0.9410)
# Saving model (epoch =  899, loss = 0.9405)
# Saving model (epoch =  903, loss = 0.9396)
# Saving model (epoch =  913, loss = 0.9367)
# Saving model (epoch =  918, loss = 0.9361)
# Saving model (epoch =  937, loss = 0.9309)
# Saving model (epoch =  947, loss = 0.9295)
# Saving model (epoch =  955, loss = 0.9291)
# Saving model (epoch =  960, loss = 0.9277)
# Saving model (epoch =  965, loss = 0.9262)
# Saving model (epoch =  970, loss = 0.9235)
# Saving model (epoch =  975, loss = 0.9232)
# Saving model (epoch =  979, loss = 0.9226)
# Saving model (epoch =  981, loss = 0.9212)
# Saving model (epoch =  990, loss = 0.9195)
# Saving model (epoch =  992, loss = 0.9191)
# Saving model (epoch =  994, loss = 0.9182)
# Saving model (epoch = 1006, loss = 0.9173)
# Saving model (epoch = 1020, loss = 0.9155)
# Saving model (epoch = 1022, loss = 0.9131)
# Saving model (epoch = 1024, loss = 0.9124)
# Saving model (epoch = 1029, loss = 0.9093)
# Saving model (epoch = 1036, loss = 0.9087)
# Saving model (epoch = 1038, loss = 0.9080)
# Saving model (epoch = 1048, loss = 0.9060)
# Saving model (epoch = 1053, loss = 0.9057)
# Saving model (epoch = 1065, loss = 0.9057)
# Saving model (epoch = 1076, loss = 0.9033)
# Saving model (epoch = 1086, loss = 0.9031)
# Saving model (epoch = 1089, loss = 0.9017)
# Saving model (epoch = 1112, loss = 0.9011)
# Saving model (epoch = 1117, loss = 0.9011)
# Saving model (epoch = 1119, loss = 0.8994)
# Saving model (epoch = 1131, loss = 0.8976)
# Saving model (epoch = 1133, loss = 0.8974)
# Saving model (epoch = 1139, loss = 0.8962)
# Saving model (epoch = 1150, loss = 0.8961)
# Saving model (epoch = 1163, loss = 0.8942)
# Saving model (epoch = 1173, loss = 0.8934)
# Saving model (epoch = 1178, loss = 0.8925)
# Saving model (epoch = 1183, loss = 0.8921)
# Saving model (epoch = 1223, loss = 0.8890)
# Saving model (epoch = 1227, loss = 0.8859)
# Saving model (epoch = 1277, loss = 0.8846)
# Saving model (epoch = 1284, loss = 0.8833)
# Saving model (epoch = 1293, loss = 0.8832)
# Saving model (epoch = 1311, loss = 0.8831)
# Saving model (epoch = 1334, loss = 0.8830)
# Saving model (epoch = 1337, loss = 0.8809)
# Saving model (epoch = 1375, loss = 0.8796)
# Saving model (epoch = 1386, loss = 0.8794)
# Saving model (epoch = 1401, loss = 0.8789)
# Saving model (epoch = 1404, loss = 0.8779)
# Saving model (epoch = 1407, loss = 0.8779)
# Saving model (epoch = 1482, loss = 0.8774)
# Saving model (epoch = 1486, loss = 0.8769)
# Saving model (epoch = 1509, loss = 0.8768)
# Saving model (epoch = 1530, loss = 0.8759)
# Saving model (epoch = 1547, loss = 0.8739)
# Saving model (epoch = 1562, loss = 0.8730)
# Saving model (epoch = 1580, loss = 0.8729)
# Saving model (epoch = 1590, loss = 0.8722)
# Saving model (epoch = 1597, loss = 0.8721)
# Saving model (epoch = 1604, loss = 0.8710)
# Saving model (epoch = 1704, loss = 0.8702)
# Saving model (epoch = 1723, loss = 0.8699)
# Saving model (epoch = 1744, loss = 0.8690)
# Saving model (epoch = 1771, loss = 0.8682)
# Saving model (epoch = 1783, loss = 0.8665)
# Saving model (epoch = 1974, loss = 0.8659)
# Saving model (epoch = 2019, loss = 0.8652)
# Saving model (epoch = 2022, loss = 0.8646)
# Saving model (epoch = 2131, loss = 0.8626)
# Finished training after 2632 epochs

# %%
plot_learning_curve(model_loss_record, title='deep model')

# %%
del model
model = NeuralNet(train_set.dataset.dim).to(device)
ckpt = torch.load(config['save_path'], map_location='cpu')  # Load your best model
model.load_state_dict(ckpt)
plot_pred(validation_set, model, device)  # Show prediction on the validation set

# %% [markdown]
# ## Testing
# Get the prediction result and save it to csv file named 'prediction.csv'

# %%
def save_pred(preds, file):
    print('Saving results to {}'.format(file))
    with open(file, 'w') as fp:
        writer = csv.writer(fp)
        writer.writerow(['id', 'tested_positive'])
        for i, p in enumerate(preds):
            writer.writerow([i, p])

preds = test(test_set, model, device)  # predict COVID-19 cases with your model
save_pred(preds, 'prediction.csv')         # save prediction file to pred.csv
# Out:
# Saving results to prediction.csv

# %% [markdown]
# ## Hints for better result
# * Feature selection
# * DNN architecture
# * Training (mini-batch/optimizer/learning rate)
# * Regularization
